# %%
# %pip install anthropic python-dotenv

from dotenv import load_dotenv
from anthropic import Anthropic

client =  Anthropic()
model = "claude-sonnet-4-0"

def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages, system=None, temperature=0.5):
    message_params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
    }

    if(system != None):
        message_params["system"] = system
    
    message_response = client.messages.create(**message_params)
    add_assistant_message(messages, message_response.content[0].text)
    print("claude >", message_response.content[0].text)
# Out:
#   WARNING: The script dotenv.exe is installed in 'c:\Users\kaise\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script distro.exe is installed in 'c:\Users\kaise\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\kaise\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 65.0 MB/s  0:00:00
# ...
#
#    --------- ------------------------------  4/17 [idna]
# ...

# %%
# Build a concise python function generator

cached_messages = []

add_user_message(
    cached_messages,
    "Write a movie idea in one sentence."
)

system_prompt = """
You are a movie script writer.
"""

chat(messages=cached_messages, system=system_prompt, temperature=1.0)
# Out:
# claude > A time-traveling librarian discovers that someone is stealing famous literary works from the past, erasing them from history, and must race through different eras to stop them before all of human storytelling disappears forever.
